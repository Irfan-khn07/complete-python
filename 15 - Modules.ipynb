# %% [markdown]
# # Module
# - A group of function , variable saved to a python file(.py) which is nothing but module.\
#   ### Types of Modules
#   - Inbuilt Modules
#   - Userdefind Modules
# ## Various Possibilties of import:
# - 1. import modulename
# - 2. import module1, module2, module3
# - 3. import module 1 as m
# - 4. import module1 as m1, module2 as m2, module3 as m3
# - 5. form module import member
# - 6.  form module import member1, member2, member2
# - 7.  form module import1 as x
# - 8.  form module import*
#
# **We can access members by using module name**\
# - modulename.variable
# - module.function()\
# Various Modules: In every module, some function are avaiable what \
# what modules reated to us?\
#      in each module what functions are availlable & use of it

# %%
import ik_m as s # store in your ram

# %%
s.add(24,43)
# Out:
# 67

# %%
from ik_m import add, sub         ### isee py file me add fun bss run hoga jisee ram me space bachega

print(add(33,45))
print(sub(33,45))
# Out:
# 78
# -12

# %%
pwd # for file LOation
# Out:
# 'D:\\Data Analytics 2026\\Python by srk\\Python program srk'

# %%
#c D:\\Data Analytics 2026for chane file location

# %% [markdown]
# **EX- import irfan () to file me jo irfan.py file ra hega usme jitna bhi program hoaga sub excuted krega ram me jise space badhega.**\
# but\
# **form irfan import add(any fun name jo use krna ho) to isee directe jo function ki jaruart h bss vhi excuted hoga isee ram pe koi fark bhi nhi padega**

# %%
#ex
''' form irfan import add,mul
print(add(2,4))
print(mul(2,4))
'''
# Out:
# ' form irfan import add,mul\nprint(add(2,4))\nprint(mul(2,4))\n'

# %%
#irfan.add()
#ik.add

# %%
#form ik import *
#add()   # only fun name

# %%
import pandas as pd

pd.Series()

# %%
import pandas 

pandas.Series()

# %%
form pandas import Series

Series()

# %%
form pandas import Series as S

s()

# %%
form pandas import *


Series()

# %%
a = 50 #golbol variable

# %%
import irfan   # local variable
irfan.add(3,5)

# %%
print(a)

# %%
s.add(32,40)
# Out:
# 72

# %%
s.sub(32,40)
# Out:
# -8

# %%
s.mul(32,40)
# Out:
# 1280

# %%
s.div(32,40)
# Out:
# 0.8

# %% [markdown]
# ## Inbuilt Modules

# %%
import math

# %%
help(math)
# Out:
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#         The result is between 0 and pi.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
#         Return the arc tangent (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     atan2(y, x, /)
#         Return the arc tangent (measured in radians) of y/x.
#
#         Unlike atan(y/x), the signs of both x and y are considered.
#
#     atanh(x, /)
#         Return the inverse hyperbolic tangent of x.
#
#     cbrt(x, /)
#         Return the cube root of x.
#
# ...

# %%
math.exp(1)
# Out:
# 2.718281828459045

# %%
math.factorial(8)
# Out:
# 40320

# %%
# e= 2.71 value of e
math.e**1
# Out:
# 2.718281828459045

# %%
#fatcorial
math.factorial(3)
# Out:
# 6

# %%
math.log(100)
# Out:
# 4.605170185988092

# %%
math.log10(100)
# Out:
# 2.0

# %%
math.pow(2,3)
# Out:
# 8.0

# %%
#squre rot
math.sqrt(144)
# Out:
# 12.0

# %%
import random   # for random no

# %%
random.random()
# Out:
# 0.5129334268904586

# %%
# you want rnd no
for i in range(5):
    print(random.random())
# Out:
# 0.37082330981078027
# 0.010041269702667721
# 0.8183367189996468
# 0.14828498884224295
# 0.012354539326754899

# %%
random.randint(1,50)
# Out:
# 8

# %%
random.randrange(5,10,1)
# Out:
# 6

# %%
# for even
random.randrange(2,100,2)
# Out:
# 92

# %%
a = ["rajuu","kajuu","sonuu","monuu"]
random.choice(1)
