# %% [markdown]
# ## Operators
# - they are some characters or reserve words used to perform various operations
# ### Type of Operators
# - Arithmetic Operators
# - Assignment Operators
# - Comparison (Relational) Operators
# - Logical (boolean) Operators
# - Membership Operators
# - Identify Operators
#
# ### **Arithmatic Operators()**
#
# - Arithmatic Operators are used to perform mathmatical Operators like addition , subtraction, multipolication etc.
# -  '+ , - , * , / , //()floor , %(modulo) ,**(power) are Arithmatic Operators
# ### Arithmatic Operators Precedence
# - Paracentheis (fisrt bracrakt)
# - Exponents (secd is power)
# - floor divition (3)
# - Multiplication or Divition or Moduluo (left to right)
# - Addition or Subtraction (left to right)

# %%
#Addition
8+5
# Out:
# 13

# %%
# subtraction
8-5
# Out:
# 3

# %%
#multiplication
8*5
# Out:
# 40

# %%
#divition - always gives out as float
8/5
# Out:
# 1.6

# %%
#floor dicition - computes the quotient (as int)
8//5
# Out:
# 1

# %%
#modulo - computes the remainder
8%5
# Out:
# 3

# %%
# exponent
10 **2  # 10 is base and ** this is power 2 is hear power its mins 100*100
# Out:
# 100

# %%
4 **8 # its min 4*4*4...8 times
# Out:
# 65536

# %%
# paracentheis
(3*5)
# Out:
# 15

# %%
5/0 # infintive its give error
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 5/0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ## when we use arthimetic operators, the boolean values will be automatically converted to int

# %%
True + True # its mins 1 + 1
# Out:
# 2

# %%
a = 23.4
b = False
a*b
# Out:
# 0.0

# %%
b/a
# Out:
# 0.0

# %%
a = 23.4
b = True
a*b
# Out:
# 23.4

# %%
5+5-5/5*5
# Out:
# 5.0

# %%
10-5+4
# Out:
# 9

# %% [markdown]
# ### **Assignment Operators**
# - Assignment Operators are used in python to assign values to variables.
# - (=, +=, -=, *=, /=, %=, //=, **= ) are Assignment Operators
# - First right side part will be executed and then value will be assigned to the left side variable

# %%
x = 10
x = x+5
print(x)
# Out:
# 15

# %%
x = 10
x+=5
print(x)
# Out:
# 15

# %%
x = 10
x*=4
print(x)
# Out:
# 40

# %% [markdown]
# ### Comparison / Relational Operators
# - Comparison Operators are used to campare values.
# - it either returns True or False accoding to the condition.
# - == , != , > , < , >= , <= are Comparison Operators

# %%
10 == 10.0
# Out:
# True

# %%
2 == 3
# Out:
# False

# %%
3 != 5
# Out:
# True

# %%
5>2
# Out:
# True

# %%
#grater then
5>=3
# Out:
# True

# %%
# less than
5<4
# Out:
# False

# %%
"raj" == "Raj"
# Out:
# False

# %% [markdown]
# ### Logical Operators / Boolean Operators
# -  Logical Operators are used to check multipal conditions at a time.
# - It returns Bool type only
# - **and, or, not** are Logical Operators.
# - when we have, **or operators** ...atlist 1 condtion should be True then only overall output will be True.
# - when we have, **and operators** ...all condtion should be True then only overall output will be True.
#
#   ## Logical Operators Precedence
#   - Logical NOT
#   - Logical AND
#   - Logical OR

# %%
# or oprator --- atlist one condtion is true
123 == 10 or 12!= 50
# Out:
# True

# %%
10 != 10 or 12== 50
# Out:
# False

# %%
# and --- all condtion true
5>3 and 1<8
# Out:
# True

# %%
5 > 3 or 2 > 3 and 5 > 4
# Out:
# True

# %%
False or not (5>2) and Ture
# Out:
# False

# %% [markdown]
# ### **Identify Opertors**
# - **Identify Opertors** are used to check if two values (or variable) are indicating to same object or not
# - It return output as boolean
# - **is, is not** are the identify operators in python
# - **is** operator(# is - True operators are identical)
# - **is not** operator (# is not - True if the operator are not identical)

# %%
a = [1,2,3,4]
b = a 
print(a is b)
print(a==b)
id(a) , id(b)
# Out:
# True
# True
# (1745398483968, 1745398483968)

# %%
a = 4
b = 4
print(a is b)
id(a)==id(b)
# Out:
# True
# True

# %%
# Is not
a =5
b =3
print(a is not b)
# Out:
# True

# %% [markdown]
# ## Membership Operators
# - Used to test whether a variable is found in a sequence (string, list, tuple, set, dictionary)
# - it returns output as boolean
# - **in , not in** are the Membership Operators.

# %%
a = 'irfan'
'an' in a # if have then True
# Out:
# True

# %%
'kh' in a
# Out:
# False

# %%
lst = [1,2,3,4,5,6]
3 in lst
# Out:
# True

# %%
0 not in lst
# Out:
# True

# %%
5 not in lst
# Out:
# False
