# %% [markdown]
# # 01 - Variable
# # 02 - Output in python(print)
# # 03 - int, float, bool, string, complex
# # 04 - input()
# # 05 - Indexing & Slicing
# # 06 - Stringd Methods

# %% [markdown]
# ## Comments in python ##

# %%
#my name is irfan (single line comment use # , during excude comment cant sow)

# %%
"""this is
multipal
line comment usee tripal comma
"""
# Out:
# 'this is\nmultipal\nline comment usee tripal comma\n'

# %%
print("im stating learning about data analytics") # what ever im writting its not excudate during print
# Out:
# im stating learning about data analytics

# %%
print(432146)
# Out:
# 432146

# %%
print("my name is raj")
print(39688)
print('irfan khna')
# Out:
# my name is raj
# 39688
# irfan khna

# %%
print(234*62572342)
# Out:
# 14641928028

# %% [markdown]
# # data type
# ### 1 Fundamental : those object can store only one value.
# #### ex:- Int(a single numeracal without decimal) , Flot( with deciaml) , Complax(a+bj -- mins real no + imgnary no) , Boolen (True and Flase) , String (A non numerical data)
# ### 2 Adavnce data type : those obj can store more then one value >1 in side obje   (br diffrant)
# #### ex:- List [...] squar br , Tuple (....) parenthesis , Set {....} curle br , Dictionary {"a": ...} curle br fist difin

# %%
print(type(2489))  # integer
# Out:
# <class 'int'>

# %%
print(type(24.38)) # flot
# Out:
# <class 'float'>

# %%
a = 2+66j # for reaal (a.real) , (a.img)
print("this is real no",a.real)    # "iske andar jo jaise likhenge waise hi rhega"    
print("this is imagnary no",a.imag)  # , use for seprater bw
# Out:
# this is real no 2.0
# this is imagnary no 66.0

# %%
print(type(2+66j)) # complex
# Out:
# <class 'complex'>

# %%
print(type(True)) # boolen
# Out:
# <class 'bool'>

# %%
print(type("sona kumar ")) # srtimng '..'
# Out:
# <class 'str'>

# %%
l=[12,487,891,536]

# %%
print(type(l))
# Out:
# <class 'list'>

# %%
t = ('irfan', 'khana', 'sona', 'mona' , 'raju', 'kaju')

# %%
print(type(t))
# Out:
# <class 'tuple'>

# %%
s = {69,87.6}

# %%
print(type(s))
# Out:
# <class 'set'>

# %%
d = {"a":'raju kumar', "b":'sohan' ,"c":'rajesh'}

# %%
print(type(d))
# Out:
# <class 'dict'>

# %% [markdown]
# # Function :-  take some intput and give output
# ### ex :- print(display text) , len(no of items) , import(Accepts user input from the console) , range(gen sequence of no) , type(rtn data of give obj) , str(convert data into a string) , int(cont data in itneger), sum(), max() , mim() , avg() etc

# %%
s1 = 'hello' # no diff
s2 = "hello"  # no diff
s3 = '''hello'''  # no diff
s4 = """hello"""
s5 = '''kalu
bhalu
chalu'''  # multi line str ke loye '''.........'''' use karenge
s6 = "kalu bhalu chalu" # singal line str
s7 = "kalu","bhalu","chalu" # multipal line str
print(s1 , s2, s3 , s4)
print(s5)
print(s6)
peint (s 7)
# Out:
# hello hello hello hello
# kalu
# bhalu
# chalu
# kalu bhalu chalu

# %% [markdown]
# ## Immutable : - Once a value is assigned to a object the value inside the object can't modified. (int,flot,complex,bool,str,truple)
# ## Mutable : - Once a value is assigned to a object the value inside the object can modified. (list,set,dict)
# ### Modification : - add , del, replaling
# #### Ex

# %%
a= 45  # Immutable
print(id(a))
a= 46
print(id(a))
# Out:
# 140720545577256
# 140720545577288

# %%
l = [1,2,3,4,5] #Mutable
id(l)  # for printing stor location id
# Out:
# 2060282269184

# %%
l[1] = 20  ## for replace 1 to 20 to see this is mutable or not
id(l) ## both id are same let see
# hance prove this is Mutable
# Out:
# 2060282269184

# %%
t = (1,2,34,4,5)  # truple lets see what happen
print(t)
print(type(t))
print(id(t))
# Out:
# (1, 2, 34, 4, 5)
# <class 'tuple'>
# 2060282052368

# %%
t(1) = 20
id(t) ## i hope its will give error bucause truple is Immutable
# Out:
#   Cell In[73], line 1
#     t(1) = 20
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?

# %% [markdown]
# ### day 11
# ### Daynaming programing :- Selecting data types automatically based on value. ex- x = 20
# ### Functional programing :- within the fun if one more fun executed. ex- print(type(x))
# ### Type Casting :- converting one datatype to another data type. ex- x=20 , then flot(x) if not poosible the give type error.
# #### When u convert boolen to int ------> True (1) & False (0)

# %%
x = 20 # int value convert to flot , str , bool
print(x)
print(float(x))
print(bool(x))
print(str(x))
# Out:
# 20
# 20.0
# True
# 20

# %%
y = -45.98 # float value convert to int , str , bool
print(int(y))
print(bool(y))
print(str(y))
print(round(y))
# Out:
# -45
# True
# -45.98
# -46

# %%
str(y)
# Out:
# '-45.98'

# %%
z = False
int(z)
# Out:
# 0

# %%
z = True   # bool to str
str(z)
float(z)
# Out:
# 1.0

# %%
# string can be coverted to int & float(not more then 1 decimal) only string has numerical characters only
z = '3425345'
int(z)
float(z)
# Out:
# 3425345.0

# %%
z = "46.78" # not con into int
int(z)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 z = "46.78" # not con into int
# ----> 2 int(z)
#
# ValueError: invalid literal for int() with base 10: '46.78'

# %%
a = str(bool(float(54.6+4.4*0)))
a
# Out:
# 'True'

# %%
bool(0)
# Out:
# False

# %%
# for ask the usar fu name input() ex:-
# by diffalt its store in string
x = input()
# Out:
#  123476

# %%
print(x)
print(type(x))
# Out:
# 123476
# <class 'str'>

# %%
# if i want to store value in other data type then use ex - x = int(input()) , float(input()) , bool(input())
x = int(input())
# Out:
#  457859486

# %%
print(x)
print(type(x))
# Out:
# 457859486
# <class 'int'>

# %%
x = int(input("enter your age:")) # inside ".....:" at its outside box
# Out:
# enter your age: 20

# %% [markdown]
# ## * input()* - use for users enter somthing. ex- x= input()  & automatic set data into 'str'
# ### eval() - use for automatically select data related to value
# #### eval() - numerical valuse not for string

# %%
v = eval(input("Enter your age :"))
# Out:
# Enter your age : 19.7

# %%
type(v)
# Out:
# float

# %%
# aske user to enter your weight
weight = eval(input("Enter your weight :"))
# Out:
# Enter your weight : 78

# %%
print(weight)
print(type(weight))
# Out:
# 64.56
# <class 'float'>

# %%
# write a program for user wight , age and name
name = input("Enter your name : ")
wight = eval(input("Enter your weight :"))
age =   eval(input("Enter your age :" ))
print("Name :",name, "Age :",age, "Weight :",weight)
# Out:
# Enter your name :  irfan khan
# Enter your weight : 67
# Enter your age : 21
# Name : irfan khan Age : 21 Weight : 64.56

# %% [markdown]
# # Day 12

# %% [markdown]
# ## Indexing and sliacing
# ### indexing :- extracting or selecting a single character in a string (list,tuuple,set,dict,set) indexing can't applied on int, float, bool
# ##### +pv indexing star for 0 to len() -1 and -neg start from -1
# ## Slicing :- extracting or selecting a more then one character in a string (use for multipal indexing) SYNTEX :- variable_name = [strating iodex no : ending indexing no]
# #### Note :- In jupyter notebook,  the last line of the call either will be print or store

# %%
s = 'hello' ### single indeexing
s[3]
# Out:
# 'l'

# %%
# if i  want to extracting int or float, bool value then use this
a = 68579
int(str(a)[4])   # first convert int value to string then doing indexing
# Out:
# 9

# %%
f = 567.657 # indexzing
float(str(f)[2])
len(str(f))
# Out:
# 7

# %%
# if indeing or slicing is worng its give emporty error
# slicting ex
s  = 'data Analyst'
print(len(s))
print(s[7:11])
print(s[:5])
# Out:
# 12
# alys
# data

# %%
s[-9:8] # +pv direction
# Out:
# 'a Ana'

# %%
s[-3:1]  # its give empoty bucause its not  possible -nve indexing
# Out:
# ''

# %%
s[-10]
# Out:
# 't'

# %%
# Multipal
s[1:10:+1]
# Out:
# 'ata Analy'

# %%
s[1:10:+2]
# Out:
# 'aaAay'

# %%
s[1:10:+3]
# Out:
# 'a a'

# %%
s[1:10:-1]   # bucause -neg direction not  possibale
# Out:
# ''

# %%
# revers
s[ : :-1]
# Out:
# 'tsylanA atad'

# %%
s = 'siva rama krishna'
# extrated rama
s[5:9:1]
# Out:
# 'rama'

# %% [markdown]
# ## day 13 STRING METHODS
# ### Methods :- are also similar kind of functions appLIcaBLE FOr a particular datatype ex:- upper() ---> function & s.upper() ---> string mathods

# %% [markdown]
# ## str.upper() * (use for string)
# ## retrun a copy of string with all characters in upparcase

# %%
s = "Hello..1232"
s.upper()
# Out:
# 'HELLO..1232'

# %%
s = 345425
s.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 s = 345425
# ----> 2 s.upper()
#
# AttributeError: 'int' object has no attribute 'upper'

# %% [markdown]
# ## str.lower()
# ## retruns  a copy of shring with all characters in lowercase

# %%
s = "IRFAN KHAN 90 Raaj"
s.lower()
# Out:
# 'irfan khan 90 raaj'

# %% [markdown]
# ## str.swapcase()
# ### returns  a copy of string with all uppercase charaters converted to lower case & viceversa (upper to lower and lower to upper)

# %%
s = "IrfAN KhaN ISSseeee AcHA"
s.swapcase()
# Out:
# 'iRFan kHAn issSEEEE aCha'

# %% [markdown]
# ## str.capitalize()
# ### returns a copy of string with first letter capitilized and remaning all to lowercase

# %%
s = "hELLow WOrlD"
s.capitalize()
# Out:
# 'Hellow world'

# %% [markdown]
# ## str.title()
# ### * returns a copy of string with first letter in each word captialized
# ### captalize  each word ms word

# %%
s = "gOOD mOrNINg"
s.title()
# Out:
# 'Good Morning'

# %% [markdown]
# ## str.strip() ---- for remove the space
# ### returns a copy of the string with leading & trailing whitespace removed

# %%
s = "  Python is easy          "
s.strip()
# Out:
# 'Python is easy'

# %% [markdown]
# ## str.lstrip() ----- removed left side space

# %%
s = " python  "
s.lstrip()
# Out:
# 'python  '

# %% [markdown]
# ## str.rstrip() ----- removed right side space

# %%
s = " python  "
s.rstrip()
# Out:
# ' python'

# %% [markdown]
# ## str.remove() ----- replace the old string with new string

# %%
s = "Good Good Morning"
print(s)
# Out:
# Good Good Morning

# %%
s = s.replace("Good", "Baad")  ## s = .... for store value then sow
print(s)
# Out:
# Baad Baad Morning

# %% [markdown]
# ## str.split()
# ### * split the string into a list substring based on the specified delimiter
# ### * if no delimiter is specified , then whitespace is selected as default delimiter

# %%
s = "my name is SRK"  ### saprate part divied 
s.split()
# Out:
# ['my', 'name', 'is', 'SRK']

# %%
# empl a vicla no and i want only no then
s = "UP56 AW 3948"
str(s.split())
int(s[8:12])
# Out:
# 3948

# %% [markdown]
# ## str.join()
# ### * join  list of string a single , using a specified delimiter (jo bhi cha ya space samble chhiye o add kr lo)

# %%
s = "siva","rama","krishna"  # truple
"".join(s)   # "" ---- pincal inside what you write print with this
# Out:
# 'sivaramakrishna'

# %%
" ".join(s)
# Out:
# 'siva rama krishna'

# %%
" and ".join(s)
# Out:
# 'siva and rama and krishna'

# %%
"::".join(s) #two cloume
# Out:
# 'siva::rama::krishna'

# %% [markdown]
# ## str.index()
# ### * returns the index of the occurence of the string searched for. (raises value error if not found)

# %%
s = "python is very esay"
s.index("is")
# Out:
# 7

# %% [markdown]
# ## s.find()
# ### * returns the index of the first occurence of the substring in a string
# ### * returns -1 if the substring is not found

# %%
s = "python is very easy"
s.find("very")
# s.find("srk")  its give value error bucause srk not abblilible
# Out:
# 10

# %%
s.find("srk")  # givw -1 error
# Out:
# -1

# %%
# its give only +pvt no only
# diff bw s.index (value error) and s.find (-1)

# %% [markdown]
# ## str.count()
# ### * returns the number of no-overlapping occurences of a substring in the searched string

# %%
s = "Good GOOD Good Good Morning"
s.count("Good")
# Out:
# 3

# %% [markdown]
# ## str.starstwith() --- for strating charecter
# ### * returns a boolean stating whether a string starts with the sprecified prefix

# %%
s = "Siva123"
s.startswith('Si') #true
#s.startswith('Sib') false
# Out:
# True

# %% [markdown]
# ## str.endswith() --- for end charecter
# ### * returns a boolean stating whether a string ends with the sprecified prefix

# %%
s = "Siva123"
s.endswith('Si') # false 
#s.endswith('123') true
# Out:
# False

# %%
s.endswith('123')
# Out:
# True

# %% [markdown]
# ## str.isalnum() --- letters and digits only with mix allow not single one
# ### * returns a boolean stating whethers a string contains only letters & digits

# %%
s = "Sivam123"
s.isalnum()
# Out:
# True

# %%
s = 'siva..2435'
s.isalnum()
# Out:
# False

# %% [markdown]
# ## str.isalpha() --- letters  only
# ### * returns a boolean stating whethers a string contains only letters

# %%
s = 'jsafktufdkhfvsdkut'
s.isalpha()
# Out:
# True

# %% [markdown]
# ## str.isdigit() --- digit  only
# ### * returns a boolean stating whethers a string contains only digit

# %%
s = '3680'
s.isdigit()
# Out:
# True

# %% [markdown]
# ## str.islower() --- lowercase
# ### * returns a boolean stating whethers a string is in lower case

# %%
s = "siva...123"
#s = "sivA...123"
s.islower()
# Out:
# True

# %% [markdown]
# ## str.isupper() --- upper case
# ### * returns a boolean stating whethers a string is in upper case

# %%
s = "IRFAN4-5678"
s.isupper()
# Out:
# True

# %% [markdown]
# ## str.istitle() --- title case
# ### * returns a boolean stating whethers a sting in title case

# %%
s = 'Siva Ram Krishna'
# s = 'siva Ram Krishna'
s.istitle()
# Out:
# True

# %% [markdown]
# ## str.removeprefix() ---
# ### * returns a string with the given prefix string removed if present

# %%
s = "NIT-Python"
s.removeprefix("NIT")
# Out:
# '-Python'

# %%
s = ".....-Python"
s.removeprefix("123")  # 123 nhi h to ans -pyhton i rhega
# Out:
# '.....-Python'

# %% [markdown]
# ## str.removesuffix() ---
# - returns a string with the given suffix string removed if present.

# %%
s = "Python..."
s.removesuffix("...")
# Out:
# 'Python'

# %% [markdown]
# ## string concatenation : adding 2 or more string

# %%
a = "irfan" + "khan"
a
# Out:
# 'irfankhan'

# %%
"irfan" + " " + "khan"
# Out:
# 'irfan khan'
